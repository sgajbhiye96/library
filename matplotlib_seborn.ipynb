# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
x=[1,2,3,4,5,6]
y=[10,13,17,18,21,25]
z=[10,20,30,40,50,60]
#line chart
plt.title("Line Chart")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x,y,color="red",linestyle='--')
plt.plot(x,z)
plt.show()

# %%
sns.lineplot(x=x,y=y,color="green")
plt.title("Line Chart")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %%
course=["DA","DS","AIML","GENAI","Agentic AI"]
z=[10,20,30,40,50,60]
#Bar chart
plt.title("Bar Chart")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.bar(x,y,color="red")

plt.show()

# %%
course=["DA","DS","AIML","GENAI","Agentic AI"]
z=[10,20,30,40,50,60]
#Bar chart
plt.title("Bar Chart")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.barh(x,y,color="red")

plt.show()

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.hist(df.total_bill)
plt.show()

# %%
x=np.log(df.total_bill)

# %%
plt.hist(x)
plt.show()

# %%
sns.distplot(x=df.total_bill,kde=True,hist=False)
# Out:
# C:\Users\CM617YH\AppData\Local\Temp\ipykernel_54384\2553270747.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df.total_bill,kde=True,hist=False)
# <Axes: ylabel='Density'>

# %%
plt.boxplot(df.total_bill)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14e637ba0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14e637ba350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14e637b9f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x14e637ba5d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14e637ba710>],
#  'means': []}

# %%
sns.boxplot(x=df.total_bill,hue=df.day)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(x=df.tip,hue=df.sex)
# Out:
# <Axes: xlabel='tip'>

# %%
import pandas as pd
correlation = df[["total_bill", "tip"]].corr(numeric_only=True)
print(correlation)
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.scatterplot(x=df.total_bill,y=df.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.scatter(df.total_bill,y=df.tip)

# %%
sns.heatmap(df[["total_bill", "tip"]].corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
num=[10,20,30,45]
plt.pie(df.sex.value_counts(),labels=["Male","Female"],autopct="%.2f",explode=[0.2,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x14e6ed774d0>,
# ...
#  [Text(-0.5662024449932367, 1.1702199755959053, 'Male'),
#   Text(0.47909422701878684, -0.990186205537762, 'Female')],
#  [Text(-0.34843227384199177, 0.72013536959748, '64.34'),
#   Text(0.2613241238284292, -0.5401015666569611, '35.66')])

# %%
sns.countplot(df.day)
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.jointplot(x=df.total_bill,y=df.tip)

# %%
sns.pairplot(df)
